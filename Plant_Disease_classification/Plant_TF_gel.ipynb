# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models, transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import time

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU")

# Transforms pour ResNet
transform_resnet = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.RandomRotation(15),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

# Dataset
from google.colab import drive
drive.mount('/content/drive')

# Unzip les dataset dans /tmp
# !unzip -q "/content/drive/MyDrive/IA201/plant.zip" -d "/tmp/plant"
# Out:
# Tesla T4
# Mounted at /content/drive

# %%
# Script to split the dataset into training and testing sets
import os
import glob
import shutil
import numpy as np

train_path = '/tmp/plant/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train'
new_train_path = '/tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/train'
new_test_path = new_train_path.replace('train', 'test')

subfolders = [ f.path for f in os.scandir(train_path) if f.is_dir() ]
test_percent = 0.2

for folder in sorted(subfolders):

    # For each subfolder, create a dictionary with the key as the image name
    # and the value as a list of all the filenames that contain that key
    filenames = sorted(glob.glob(os.path.join(folder, '*')))
    if 'Corn_(maize)___Common_rust_' in folder:
        keys = [f.split('/')[-1][:12] for f in filenames]
    else:
        keys = [f.split('/')[-1].split('_')[0] for f in filenames]
    keys = np.unique(keys)

    image_dict = {}

    # Create a dictionary with the key as the image name and the value as a list of all the filenames that contain that key
    for key in keys:
        image_dict[key] = []
        for filename in filenames:
            if key in filename:
                image_dict[key].append(filename)

    n_images = len(keys)
    print(f'There are {len(keys)} unique images in the folder {folder}')

    n_train = int(n_images * (1 - test_percent))
    n_test = n_images - n_train

    idx = np.arange(n_images)
    np.random.shuffle(idx)
    train_idx = idx[:n_train]
    test_idx = idx[n_train:]

    # Create the train and test folders
    train_folder = os.path.join(new_train_path, os.path.basename(folder))
    test_folder = os.path.join(new_test_path, os.path.basename(folder))
    os.makedirs(train_folder, exist_ok=True)
    os.makedirs(test_folder, exist_ok=True)
    print(f'Creating {train_folder} and {test_folder}')
    # Copy the files to the train and test folders
    for i in train_idx:
        for filename in image_dict[keys[i]]:
            shutil.copy(filename, train_folder)
    for i in test_idx:
        for filename in image_dict[keys[i]]:
            shutil.copy(filename, test_folder)

# Copy the validation folder
# shutil.copytree('plants-disease-dataset/valid', 'new-plants-disease-dataset/valid')


old_train_filenames = sorted(glob.glob(os.path.join(train_path, '*/*')))
train_filenames = sorted(glob.glob(os.path.join(new_train_path, '*/*')))
test_filenames = sorted(glob.glob(os.path.join(new_test_path, '*/*')))

print('Before: train images:', len(old_train_filenames))
print('After: train images:', len(train_filenames))
print('After: test images:', len(test_filenames))

if len(old_train_filenames) != len(train_filenames) + len(test_filenames):
    print('Error: the number of images in the old train folder is not equal to the sum of the new train and test folders')
else:
    print('Success: the number of images in the old train folder is equal to the sum of the new train and test folders')
# Out:
# There are 630 unique images in the folder /tmp/plant/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Apple___Apple_scab
# Creating /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/train/Apple___Apple_scab and /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/test/Apple___Apple_scab
# There are 619 unique images in the folder /tmp/plant/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Apple___Black_rot
# Creating /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/train/Apple___Black_rot and /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/test/Apple___Black_rot
# There are 275 unique images in the folder /tmp/plant/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Apple___Cedar_apple_rust
# Creating /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/train/Apple___Cedar_apple_rust and /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/test/Apple___Cedar_apple_rust
# There are 1466 unique images in the folder /tmp/plant/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Apple___healthy
# Creating /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/train/Apple___healthy and /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/test/Apple___healthy
# There are 1231 unique images in the folder /tmp/plant/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Blueberry___healthy
# Creating /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/train/Blueberry___healthy and /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/test/Blueberry___healthy
# There are 1003 unique images in the folder /tmp/plant/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Cherry_(including_sour)___Powdery_mildew
# Creating /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/train/Cherry_(including_sour)___Powdery_mildew and /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/test/Cherry_(including_sour)___Powdery_mildew
# There are 825 unique images in the folder /tmp/plant/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Cherry_(including_sour)___healthy
# Creating /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/train/Cherry_(including_sour)___healthy and /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/test/Cherry_(including_sour)___healthy
# There are 512 unique images in the folder /tmp/plant/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot
# Creating /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/train/Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot and /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/test/Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot
# There are 1144 unique images in the folder /tmp/plant/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Corn_(maize)___Common_rust_
# Creating /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/train/Corn_(maize)___Common_rust_ and /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/test/Corn_(maize)___Common_rust_
# There are 918 unique images in the folder /tmp/plant/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Corn_(maize)___Northern_Leaf_Blight
# Creating /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/train/Corn_(maize)___Northern_Leaf_Blight and /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/test/Corn_(maize)___Northern_Leaf_Blight
# There are 1112 unique images in the folder /tmp/plant/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Corn_(maize)___healthy
# Creating /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/train/Corn_(maize)___healthy and /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/test/Corn_(maize)___healthy
# There are 1136 unique images in the folder /tmp/plant/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Grape___Black_rot
# Creating /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/train/Grape___Black_rot and /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/test/Grape___Black_rot
# There are 1279 unique images in the folder /tmp/plant/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Grape___Esca_(Black_Measles)
# Creating /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/train/Grape___Esca_(Black_Measles) and /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/test/Grape___Esca_(Black_Measles)
# There are 1029 unique images in the folder /tmp/plant/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Grape___Leaf_blight_(Isariopsis_Leaf_Spot)
# Creating /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/train/Grape___Leaf_blight_(Isariopsis_Leaf_Spot) and /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/test/Grape___Leaf_blight_(Isariopsis_Leaf_Spot)
# There are 423 unique images in the folder /tmp/plant/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Grape___healthy
# Creating /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/train/Grape___healthy and /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/test/Grape___healthy
# There are 2010 unique images in the folder /tmp/plant/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Orange___Haunglongbing_(Citrus_greening)
# Creating /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/train/Orange___Haunglongbing_(Citrus_greening) and /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/test/Orange___Haunglongbing_(Citrus_greening)
# There are 1838 unique images in the folder /tmp/plant/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Peach___Bacterial_spot
# Creating /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/train/Peach___Bacterial_spot and /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/test/Peach___Bacterial_spot
# There are 360 unique images in the folder /tmp/plant/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Peach___healthy
# Creating /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/train/Peach___healthy and /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/test/Peach___healthy
# There are 936 unique images in the folder /tmp/plant/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Pepper,_bell___Bacterial_spot
# Creating /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/train/Pepper,_bell___Bacterial_spot and /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/test/Pepper,_bell___Bacterial_spot
# There are 1205 unique images in the folder /tmp/plant/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Pepper,_bell___healthy
# Creating /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/train/Pepper,_bell___healthy and /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/test/Pepper,_bell___healthy
# There are 935 unique images in the folder /tmp/plant/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Potato___Early_blight
# Creating /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/train/Potato___Early_blight and /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/test/Potato___Early_blight
# There are 937 unique images in the folder /tmp/plant/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Potato___Late_blight
# Creating /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/train/Potato___Late_blight and /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/test/Potato___Late_blight
# There are 152 unique images in the folder /tmp/plant/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Potato___healthy
# Creating /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/train/Potato___healthy and /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/test/Potato___healthy
# There are 371 unique images in the folder /tmp/plant/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Raspberry___healthy
# Creating /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/train/Raspberry___healthy and /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/test/Raspberry___healthy
# There are 2022 unique images in the folder /tmp/plant/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Soybean___healthy
# Creating /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/train/Soybean___healthy and /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/test/Soybean___healthy
# There are 1525 unique images in the folder /tmp/plant/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Squash___Powdery_mildew
# Creating /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/train/Squash___Powdery_mildew and /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/test/Squash___Powdery_mildew
# There are 1064 unique images in the folder /tmp/plant/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Strawberry___Leaf_scorch
# Creating /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/train/Strawberry___Leaf_scorch and /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/test/Strawberry___Leaf_scorch
# There are 456 unique images in the folder /tmp/plant/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Strawberry___healthy
# Creating /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/train/Strawberry___healthy and /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/test/Strawberry___healthy
# There are 1702 unique images in the folder /tmp/plant/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Tomato___Bacterial_spot
# Creating /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/train/Tomato___Bacterial_spot and /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/test/Tomato___Bacterial_spot
# There are 944 unique images in the folder /tmp/plant/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Tomato___Early_blight
# Creating /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/train/Tomato___Early_blight and /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/test/Tomato___Early_blight
# There are 1592 unique images in the folder /tmp/plant/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Tomato___Late_blight
# Creating /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/train/Tomato___Late_blight and /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/test/Tomato___Late_blight
# There are 892 unique images in the folder /tmp/plant/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Tomato___Leaf_Mold
# Creating /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/train/Tomato___Leaf_Mold and /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/test/Tomato___Leaf_Mold
# There are 1455 unique images in the folder /tmp/plant/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Tomato___Septoria_leaf_spot
# Creating /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/train/Tomato___Septoria_leaf_spot and /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/test/Tomato___Septoria_leaf_spot
# There are 1385 unique images in the folder /tmp/plant/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Tomato___Spider_mites Two-spotted_spider_mite
# Creating /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/train/Tomato___Spider_mites Two-spotted_spider_mite and /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/test/Tomato___Spider_mites Two-spotted_spider_mite
# There are 1167 unique images in the folder /tmp/plant/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Tomato___Target_Spot
# Creating /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/train/Tomato___Target_Spot and /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/test/Tomato___Target_Spot
# There are 1961 unique images in the folder /tmp/plant/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Tomato___Tomato_Yellow_Leaf_Curl_Virus
# Creating /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/train/Tomato___Tomato_Yellow_Leaf_Curl_Virus and /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/test/Tomato___Tomato_Yellow_Leaf_Curl_Virus
# There are 373 unique images in the folder /tmp/plant/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Tomato___Tomato_mosaic_virus
# Creating /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/train/Tomato___Tomato_mosaic_virus and /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/test/Tomato___Tomato_mosaic_virus
# There are 1318 unique images in the folder /tmp/plant/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Tomato___healthy
# Creating /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/train/Tomato___healthy and /tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/test/Tomato___healthy
# Before: train images: 70295
# After: train images: 56122
# After: test images: 14173
# Success: the number of images in the old train folder is equal to the sum of the new train and test folders

# %%
train_dataset = ImageFolder("/tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/train", transform=transform_resnet)
valid_dataset = ImageFolder("/tmp/plant/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/valid", transform=transform_resnet)
test_dataset = ImageFolder("/tmp/plant/New Plant Diseases Dataset(Augmented)/plants-dataset/test", transform=transform_resnet)

BATCH_SIZE = 128
NUM_WORKERS = 8

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS)
valid_loader = DataLoader(valid_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS)

# MODELE AVEC FEATURE EXTRACTION
def get_frozen_resnet18():
    model = models.resnet18(pretrained=True)
    for param in model.parameters():
        param.requires_grad = False
    num_features = model.fc.in_features
    model.fc = nn.Sequential(
        nn.Linear(num_features, 128),
        nn.ReLU(),
        nn.Dropout(0.4),
        nn.Linear(128, 38)
    )
    return model.to(device)

# MODELE AVEC FINE-TUNING
def get_finetuned_resnet18():
    model = models.resnet18(pretrained=True)
    for name, param in model.named_parameters():
        if "layer3" in name or "layer4" in name or "fc" in name:
            param.requires_grad = True
        else:
            param.requires_grad = False
    num_features = model.fc.in_features
    model.fc = nn.Sequential(
        nn.Linear(num_features, 128),
        nn.ReLU(),
        nn.Dropout(0.4),
        nn.Linear(128, 38)
    )
    return model.to(device)
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(

# %%
# Choix du modèle :
model = get_frozen_resnet18()

# Optimizer et loss
trainable_params = filter(lambda p: p.requires_grad, model.parameters()) # Choix des param en fonction du modele

criterion = nn.CrossEntropyLoss()
optimizer = optim.AdamW(trainable_params, lr=0.0005, betas=(0.9, 0.999))

# Entraînement
model.train()

loss_list = []
loss_list_idx = []
acc_list = []
val_acc_list = []
val_loss_list = []

compteur = 0

for epoch in range(15):
    running_loss = 0.0
    correct = 0
    total = 0
    start = time.time()

    model.train()  # Mode entraînement

    for i, (inputs, labels) in enumerate(train_loader):
        if i % 50 == 0:
            batch_start = time.time()

        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        # Prédictions pour accuracy
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

        if i % 50 == 49:
            print(f'[{epoch + 1}, {i + 1:5d}] loss: {running_loss / 50:.3f}')
            print(f"Batch {i} time: {time.time() - batch_start:.2f}s")
            loss_list.append(running_loss / 50)
            loss_list_idx.append(compteur * 50)
            running_loss = 0.0
            compteur += 1

    # Accuracy à la fin de l’époque
    epoch_acc = 100 * correct / total
    acc_list.append(epoch_acc)
    print(f'→ Accuracy après epoch {epoch + 1}: {epoch_acc:.2f}%')
    print(f"Epoch time: {time.time() - start:.2f}s")

    # Phase de validation
    model.eval()
    val_correct = 0
    val_total = 0
    val_loss = 0.0

    with torch.no_grad():
        for val_inputs, val_labels in valid_loader:
            val_inputs, val_labels = val_inputs.to(device), val_labels.to(device)
            val_outputs = model(val_inputs)
            loss = criterion(val_outputs, val_labels)
            val_loss += loss.item()

            _, val_predicted = torch.max(val_outputs.data, 1)
            val_total += val_labels.size(0)
            val_correct += (val_predicted == val_labels).sum().item()

    val_acc = 100 * val_correct / val_total
    avg_val_loss = val_loss / len(valid_loader)

    val_acc_list.append(val_acc)
    val_loss_list.append(avg_val_loss)

    print(f'→ Validation accuracy: {val_acc:.2f}% | Validation loss: {avg_val_loss:.4f}')

print('Finished Training')

# Affichage des courbes
# Train
plt.figure()
plt.subplot(1, 2, 1)
plt.plot(loss_list_idx, loss_list)
plt.title("Loss function")
plt.xlabel("Minibatch")
plt.ylabel("Loss")

plt.subplot(1, 2, 2)
plt.plot(range(1, len(acc_list) + 1), acc_list, marker='o')
plt.title("Accuracy par epoch")
plt.xlabel("Epoch")
plt.ylabel("Accuracy (%)")

# Val
plt.figure()
plt.subplot(1, 2, 1)
plt.plot(range(1, len(loss_list)//len(train_loader)+1), [np.mean(loss_list[i::len(train_loader)]) for i in range(len(train_loader))], label='Train Loss')
plt.plot(range(1, len(val_loss_list)+1), val_loss_list, label='Validation Loss')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss par epoch")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(range(1, len(acc_list)+1), acc_list, label='Train Accuracy')
plt.plot(range(1, len(val_acc_list)+1), val_acc_list, label='Validation Accuracy')
plt.xlabel("Epoch")
plt.ylabel("Accuracy (%)")
plt.title("Accuracy par epoch")
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 109MB/s]
# [1,    50] loss: 3.346
# Batch 49 time: 10.85s
# [1,   100] loss: 2.442
# Batch 99 time: 11.66s
# [1,   150] loss: 1.828
# Batch 149 time: 11.67s
# [1,   200] loss: 1.501
# Batch 199 time: 10.97s
# [1,   250] loss: 1.301
# Batch 249 time: 11.48s
# [1,   300] loss: 1.216
# Batch 299 time: 11.11s
# [1,   350] loss: 1.115
# Batch 349 time: 10.39s
# [1,   400] loss: 1.040
# Batch 399 time: 11.34s
# → Accuracy après epoch 1: 55.75%
# Epoch time: 101.51s
# → Validation accuracy: 81.04% | Validation loss: 0.7269
# [2,    50] loss: 0.970
# Batch 49 time: 11.88s
# [2,   100] loss: 0.916
# Batch 99 time: 11.37s
# [2,   150] loss: 0.888
# Batch 149 time: 10.53s
# [2,   200] loss: 0.877
# Batch 199 time: 10.84s
# [2,   250] loss: 0.807
# Batch 249 time: 11.33s
# [2,   300] loss: 0.807
# Batch 299 time: 11.65s
# [2,   350] loss: 0.770
# Batch 349 time: 11.03s
# [2,   400] loss: 0.777
# Batch 399 time: 9.85s
# → Accuracy après epoch 2: 75.03%
# Epoch time: 99.60s
# → Validation accuracy: 84.36% | Validation loss: 0.5504
# [3,    50] loss: 0.741
# Batch 49 time: 11.25s
# [3,   100] loss: 0.744
# Batch 99 time: 11.22s
# [3,   150] loss: 0.729
# Batch 149 time: 11.87s
# [3,   200] loss: 0.717
# Batch 199 time: 11.72s
# [3,   250] loss: 0.721
# Batch 249 time: 10.89s
# [3,   300] loss: 0.709
# Batch 299 time: 9.77s
# [3,   350] loss: 0.700
# Batch 349 time: 11.22s
# [3,   400] loss: 0.705
# Batch 399 time: 11.38s
# → Accuracy après epoch 3: 78.15%
# Epoch time: 100.24s
# → Validation accuracy: 86.22% | Validation loss: 0.4704
# [4,    50] loss: 0.645
# Batch 49 time: 11.36s
# [4,   100] loss: 0.686
# Batch 99 time: 11.69s
# [4,   150] loss: 0.653
# Batch 149 time: 10.03s
# [4,   200] loss: 0.663
# Batch 199 time: 11.21s
# [4,   250] loss: 0.678
# Batch 249 time: 11.41s
# [4,   300] loss: 0.644
# Batch 299 time: 11.36s
# [4,   350] loss: 0.667
# Batch 349 time: 11.40s
# [4,   400] loss: 0.616
# Batch 399 time: 10.18s
# → Accuracy après epoch 4: 79.80%
# Epoch time: 99.12s
# → Validation accuracy: 86.87% | Validation loss: 0.4395
# [5,    50] loss: 0.626
# Batch 49 time: 11.02s
# [5,   100] loss: 0.613
# Batch 99 time: 11.86s
# [5,   150] loss: 0.594
# Batch 149 time: 11.49s
# [5,   200] loss: 0.630
# Batch 199 time: 11.45s
# [5,   250] loss: 0.616
# Batch 249 time: 10.45s
# [5,   300] loss: 0.608
# Batch 299 time: 10.73s
# [5,   350] loss: 0.632
# Batch 349 time: 11.43s
# [5,   400] loss: 0.610
# Batch 399 time: 11.50s
# → Accuracy après epoch 5: 80.84%
# Epoch time: 100.15s
# → Validation accuracy: 87.38% | Validation loss: 0.4109
# [6,    50] loss: 0.614
# Batch 49 time: 11.58s
# [6,   100] loss: 0.574
# Batch 99 time: 10.63s
# [6,   150] loss: 0.624
# Batch 149 time: 10.56s
# [6,   200] loss: 0.582
# Batch 199 time: 11.79s
# [6,   250] loss: 0.578
# Batch 249 time: 11.26s
# [6,   300] loss: 0.578
# Batch 299 time: 11.41s
# [6,   350] loss: 0.588
# Batch 349 time: 11.06s
# [6,   400] loss: 0.562
# Batch 399 time: 10.17s
# → Accuracy après epoch 6: 81.59%
# Epoch time: 99.09s
# → Validation accuracy: 87.85% | Validation loss: 0.3978
# [7,    50] loss: 0.584
# Batch 49 time: 11.41s
# [7,   100] loss: 0.566
# Batch 99 time: 11.71s
# [7,   150] loss: 0.557
# Batch 149 time: 11.33s
# [7,   200] loss: 0.570
# Batch 199 time: 11.03s
# [7,   250] loss: 0.541
# Batch 249 time: 10.96s
# [7,   300] loss: 0.556
# Batch 299 time: 11.28s
# [7,   350] loss: 0.575
# Batch 349 time: 11.32s
# [7,   400] loss: 0.565
# Batch 399 time: 11.31s
# → Accuracy après epoch 7: 82.19%
# Epoch time: 98.82s
# → Validation accuracy: 88.03% | Validation loss: 0.3822
# [8,    50] loss: 0.554
# Batch 49 time: 11.06s
# [8,   100] loss: 0.549
# Batch 99 time: 10.64s
# [8,   150] loss: 0.544
# Batch 149 time: 11.33s
# [8,   200] loss: 0.562
# Batch 199 time: 11.34s
# [8,   250] loss: 0.560
# Batch 249 time: 11.27s
# [8,   300] loss: 0.561
# Batch 299 time: 11.61s
# [8,   350] loss: 0.545
# Batch 349 time: 10.27s
# [8,   400] loss: 0.551
# Batch 399 time: 11.26s
# → Accuracy après epoch 8: 82.55%
# Epoch time: 98.89s
# → Validation accuracy: 88.33% | Validation loss: 0.3704
# [9,    50] loss: 0.537
# Batch 49 time: 11.70s
# [9,   100] loss: 0.526
# Batch 99 time: 11.60s
# [9,   150] loss: 0.530
# Batch 149 time: 11.39s
# [9,   200] loss: 0.539
# Batch 199 time: 9.87s
# [9,   250] loss: 0.530
# Batch 249 time: 12.16s
# [9,   300] loss: 0.537
# Batch 299 time: 11.76s
# [9,   350] loss: 0.541
# Batch 349 time: 10.90s
# [9,   400] loss: 0.558
# Batch 399 time: 11.47s
# → Accuracy après epoch 9: 82.85%
# Epoch time: 98.90s
# → Validation accuracy: 88.40% | Validation loss: 0.3620
# [10,    50] loss: 0.519
# Batch 49 time: 10.36s
# [10,   100] loss: 0.525
# Batch 99 time: 12.07s
# [10,   150] loss: 0.538
# Batch 149 time: 11.43s
# [10,   200] loss: 0.546
# Batch 199 time: 11.55s
# [10,   250] loss: 0.527
# Batch 249 time: 11.29s
# [10,   300] loss: 0.538
# Batch 299 time: 11.70s
# [10,   350] loss: 0.532
# Batch 349 time: 9.74s
# [10,   400] loss: 0.517
# Batch 399 time: 12.13s
# → Accuracy après epoch 10: 83.27%
# Epoch time: 101.30s
# → Validation accuracy: 89.03% | Validation loss: 0.3509
# [11,    50] loss: 0.510
# Batch 49 time: 11.53s
# [11,   100] loss: 0.514
# Batch 99 time: 11.89s
# [11,   150] loss: 0.502
# Batch 149 time: 11.95s
# [11,   200] loss: 0.536
# Batch 199 time: 11.20s
# [11,   250] loss: 0.517
# Batch 249 time: 10.78s
# [11,   300] loss: 0.538
# Batch 299 time: 11.45s
# [11,   350] loss: 0.513
# Batch 349 time: 11.55s
# [11,   400] loss: 0.508
# Batch 399 time: 11.03s
# → Accuracy après epoch 11: 83.49%
# Epoch time: 100.03s
# → Validation accuracy: 89.03% | Validation loss: 0.3427
# [12,    50] loss: 0.490
# Batch 49 time: 10.22s
# [12,   100] loss: 0.504
# Batch 99 time: 11.08s
# [12,   150] loss: 0.506
# Batch 149 time: 11.16s
# [12,   200] loss: 0.500
# Batch 199 time: 11.84s
# [12,   250] loss: 0.520
# Batch 249 time: 11.17s
# [12,   300] loss: 0.509
# Batch 299 time: 10.55s
# [12,   350] loss: 0.518
# Batch 349 time: 10.96s
# [12,   400] loss: 0.519
# Batch 399 time: 11.42s
# → Accuracy après epoch 12: 83.67%
# Epoch time: 99.61s
# → Validation accuracy: 89.01% | Validation loss: 0.3390
# [13,    50] loss: 0.502
# Batch 49 time: 11.51s
# [13,   100] loss: 0.497
# Batch 99 time: 11.53s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-7a381329da54> in <cell line: 0>()
#      31             batch_start = time.time()
#      32
# ---> 33         inputs, labels = inputs.to(device), labels.to(device)
#      34
#      35         optimizer.zero_grad()
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(18, 5))  # Largeur augmentée pour 3 sous-graphes

# 1. Train Loss
plt.subplot(1, 3, 1)
plt.plot(loss_list_idx, loss_list, color='blue', label='Train Loss')
plt.title("Train Loss (minibatch)")
plt.xlabel("Minibatch")
plt.ylabel("Loss")
plt.legend()

# 2. Validation Loss par epoch
plt.subplot(1, 3, 2)
plt.plot(range(1, len(val_loss_list) + 1), val_loss_list, color='orange', label='Validation Loss')
plt.title("Validation Loss (epoch)")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

# 3. Accuracy pour Train et Validation
plt.subplot(1, 3, 3)
plt.plot(range(1, len(acc_list) + 1), acc_list, label='Train Accuracy')
plt.plot(range(1, len(val_acc_list) + 1), val_acc_list, label='Validation Accuracy')
plt.title("Accuracy par epoch")
plt.xlabel("Epoch")
plt.ylabel("Accuracy (%)")
plt.legend()

plt.tight_layout()
plt.show()


model.eval()

correct = 0
total = 0

all_preds = []
all_labels = []

with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)

        total += labels.size(0)
        correct += (predicted == labels).sum().item()

        all_preds.extend(predicted.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

# Accuracy globale
print(f'Accuracy on test set: {100 * correct / total:.2f}%')

# Matrice de confusion
cm = confusion_matrix(all_labels, all_preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)

# Affichage sans labels ni valeurs
fig, ax = plt.subplots()
disp.plot(cmap=plt.cm.Blues, ax=ax, include_values=False)

# Supprimer les ticks et les labels
ax.set_xticks([])
ax.set_yticks([])
ax.set_xlabel("")
ax.set_ylabel("")

plt.title("Matrice de confusion (sans labels ni valeurs)")
plt.tight_layout()
plt.show()
# Out:
# Accuracy on test set: 88.96%
